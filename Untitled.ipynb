# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, classification_report

# %%
df = pd.read_csv('subject_spam - subject_spam.csv.csv')

# %%
df.sample(5)
# Out:
#       Unnamed: 0                                            Subject isspam
# 7770        7770                                            #ERROR!   spam
# 5583        5583    paperloop daily news for Thursday, Nov. 8, 2001    ham
# 13232      13231  ÀÌ¸ðµÐ°Ô ¹«·á¹«·á!!°æÇ°ÀÇ ¾Ð¹Ú!!Áö±Ý ½ÅÃ»ÇØ¼­ ...   spam
# 32162      32159                 Weekly HR Newsletter - August 30th    ham
# 15598      15597                     Last Call for Houston Seminars   spam

# %%
df = df.dropna(subset=['Subject'])  # Drop rows with missing subjects
df['isspam'] = df['isspam'].str.strip()  # Remove leading/trailing whitespaces

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36939 entries, 0 to 37891
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  36939 non-null  object
#  1   Subject     36939 non-null  object
#  2   isspam      36933 non-null  object
# dtypes: object(3)
# memory usage: 1.1+ MB

# %%
df.sample(5)
# Out:
#       Unnamed: 0                                           Subject isspam
# 17945      17943                                  Fwd: Ground Zero    ham
# 8110        8110    Schedule Crawler: HourAhead Failure <CODESITE>    ham
# 5429        5429  "Christmas Around the World" & "Open Invitation"    ham
# 26899      26896                          Everyone Need This rring   spam
# 19683      19681                              You Need This KHolst   spam

# %%
df.rename(columns={'subject':'text','isspam':'target'},inplace=True)
df.sample(5)
# Out:
#       Unnamed: 0                                 Subject target
# 14036      14035             10-17-01 west power reports    ham
# 23214      23212                               YUKOS OIL   spam
# 31946      31943          NewsBeat:Daily News 11/06/2001    ham
# 9159        9159  Delivery Status Notification (Success)    ham
# 29915      29912                                 #ERROR!   spam

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#   Unnamed: 0                                            Subject  target
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0

# %%
# missing values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Subject       0
# target        0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (36939, 3)

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#   Unnamed: 0                                            Subject  target
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0

# %%
df = df[df['target'] != 2]

# Verify the rows have been removed
print(df['target'].value_counts())
# Out:
# 1    19289
# 0    17644
# Name: target, dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    19289
# 0    17644
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
import nltk

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\masah\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\masah\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\masah\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\masah\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in c:\users\masah\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\masah\anaconda3\lib\site-packages (from click->nltk) (0.4.5)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\masah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters'] = df['Subject'].apply(len)

# %%
df.head()
# Out:
#   Unnamed: 0                                            Subject  target  \
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0
#
#    num_characters
# 0              39
# 1              68
# 3              36
# 4              31
# 5              27

# %%
# num of words
df['num_words'] = df['Subject'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#   Unnamed: 0                                            Subject  target  \
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0
#
#    num_characters  num_words
# 0              39         13
# 1              68         12
# 3              36          5
# 4              31          8
# 5              27          5

# %%
df['num_sentences'] = df['Subject'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#   Unnamed: 0                                            Subject  target  \
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0
#
#    num_characters  num_words  num_sentences
# 0              39         13              1
# 1              68         12              2
# 3              36          5              1
# 4              31          8              1
# 5              27          5              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters     num_words  num_sentences
# count    36933.000000  36933.000000   36933.000000
# mean        32.452035      6.286383       1.066472
# std         21.590051      4.107439       0.281271
# min          1.000000      1.000000       1.000000
# 25%         17.000000      3.000000       1.000000
# 50%         29.000000      5.000000       1.000000
# 75%         44.000000      8.000000       1.000000
# max        408.000000     62.000000       5.000000

# %%
# ham
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters     num_words  num_sentences
# count    17644.000000  17644.000000   17644.000000
# mean        32.474949      6.113410       1.020290
# std         20.360969      3.830449       0.149956
# min          1.000000      1.000000       1.000000
# 25%         18.000000      3.000000       1.000000
# 50%         28.000000      5.000000       1.000000
# 75%         44.000000      8.000000       1.000000
# max        239.000000     62.000000       4.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters     num_words  num_sentences
# count    19289.000000  19289.000000   19289.000000
# mean        32.431075      6.444606       1.108715
# std         22.656507      4.339439       0.356621
# min          1.000000      1.000000       1.000000
# 25%         16.000000      3.000000       1.000000
# 50%         29.000000      5.000000       1.000000
# 75%         43.000000      8.000000       1.000000
# max        408.000000     49.000000       5.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <AxesSubplot:xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <AxesSubplot:xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. Data Preprocessing
# Lower case,
# Tokenization,
# Removing special characters,
# Removing stop words and punctuation,,
# Stemming,

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import string

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Initialize the Porter Stemmer
ps = PorterStemmer()

def transform_text(subject):
    subject = subject.lower()
    subject = nltk.word_tokenize(subject)
    
    y = []
    for word in subject:
        if word.isalnum():
            y.append(word)
    
    subject = y[:]
    y.clear()
    
    for word in subject:
        if word not in stopwords.words('english') and word not in string.punctuation:
            y.append(word)
            
    subject = y[:]
    y.clear()
    
    for word in subject:
        y.append(ps.stem(word))
    
    return " ".join(y)



# Apply the function to the 'Subject' column
df['transformed_subject'] = df['Subject'].apply(transform_text)

# Display the first few rows to verify the transformation
print(df.head())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\masah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\masah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   Unnamed: 0                                            Subject  target  \
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0
#
#    num_characters  num_words  num_sentences              transformed_subject
# 0              39         13              1  confidenti soma ci li p ntermin
# 1              68         12              2           çªáüçñ j cbop blraijvv
# 3              36          5              1            stock 0ppurtun sh0ote
# 4              31          8              1                cp l tariff chang
# 5              27          5              1         im draft florida project

# %%
df.head()
# Out:
#   Unnamed: 0                                            Subject  target  \
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0
#
#    num_characters  num_words  num_sentences              transformed_subject
# 0              39         13              1  confidenti soma ci li p ntermin
# 1              68         12              2           çªáüçñ j cbop blraijvv
# 3              36          5              1            stock 0ppurtun sh0ote
# 4              31          8              1                cp l tariff chang
# 5              27          5              1         im draft florida project

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_text = df[df['target'] == 1]['transformed_subject'].str.cat(sep=" ")
wc = WordCloud(width=800, height=400, background_color='white').generate(spam_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
ham_text = df[df['target'] == 0]['transformed_subject'].str.cat(sep=" ")
ham_wc = WordCloud(width=800, height=400, background_color='white').generate(ham_text)

# Display the word cloud for non-spam emails
plt.figure(figsize=(10, 5))
plt.imshow(ham_wc, interpolation='bilinear')
plt.axis('off')
plt.title('Ham Emails Word Cloud')
plt.show()

# %%
df.head()
# Out:
#   Unnamed: 0                                            Subject  target  \
# 0          0            Confidential :Soma:, Ci@lis, :P:ntermin       1
# 1          1  ¢Â ÇªÁüÇÑ ¼³³¯ ÀÌº¥Æ® ÀÀ¸ðÇØ¼­ ºÎ¸ð´Ô²² ¼±¹°ÇÏ...       1
# 3          3               StOck 0ppurtunities - their sh0Oting       1
# 4          4                    CP&L tariff changes (ER01-1807)       0
# 5          5                        IM draft - Florida Projects       0
#
#    num_characters  num_words  num_sentences              transformed_subject
# 0              39         13              1  confidenti soma ci li p ntermin
# 1              68         12              2           çªáüçñ j cbop blraijvv
# 3              36          5              1            stock 0ppurtun sh0ote
# 4              31          8              1                cp l tariff chang
# 5              27          5              1         im draft florida project

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_subject'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 58316

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\masah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_subject'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 67194

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(ham_corpus).most_common(30))[0],pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\masah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Initialize CountVectorizer
cv = CountVectorizer()

# Initialize TfidfVectorizer
tfidf = TfidfVectorizer()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TfidfVectorizer
tfidf = TfidfVectorizer()

# Fit and transform the 'transformed_subject' column to create a sparse matrix
X = tfidf.fit_transform(df['transformed_subject'])

# Print the shape of the resulting sparse matrix to see the dimensions
print(X.shape)
# Out:
# (36933, 12954)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# Initialize the MultinomialNB model
gnb = GaussianNB()

# Train the model
gnb.fit(X_train, y_train)

# Make predictions
y_pred1 = gnb.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred1))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred1))
print("Precision:", precision_score(y_test, y_pred1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15404\2156120950.py in <module>
#       6
#       7 # Train the model
# ----> 8 gnb.fit(X_train, y_train)
#       9
#      10 # Make predictions
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     243         """
#     244         y = self._validate_data(y=y)
# --> 245         return self._partial_fit(
#     246             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     247         )
#
# ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     400
#     401         first_call = _check_partial_fit_first_call(self, classes)
# --> 402         X, y = self._validate_data(X, y, reset=first_call)
#     403         if sample_weight is not None:
#     404             sample_weight = _check_sample_weight(sample_weight, X)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     962         raise ValueError("y cannot be None")
#     963
# --> 964     X = check_array(
#     965         X,
#     966         accept_sparse=accept_sparse,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718     if sp.issparse(array):
#     719         _ensure_no_complex_data(array)
# --> 720         array = _ensure_sparse_format(
#     721             array,
#     722             accept_sparse=accept_sparse,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse)
#     438
#     439     if accept_sparse is False:
# --> 440         raise TypeError(
#     441             "A sparse matrix was passed, but dense "
#     442             "data is required. Use X.toarray() to "
#
# TypeError: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9347502369026669
# [[3230  273]
#  [ 209 3675]]
# 0.9308510638297872

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9266278597536213
# [[3137  366]
#  [ 176 3708]]
# 0.9101620029455081

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
# Voting Classifier
mnb = MultinomialNB()
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
from sklearn.ensemble import VotingClassifier

# %%
voting = VotingClassifier(estimators=[('RF',rfc), ('nb', mnb)],voting='soft')

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('RF',
#                               RandomForestClassifier(n_estimators=50,
#                                                      random_state=2)),
#                              ('nb', MultinomialNB())],
#                  voting='soft')

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9500473805333695
# Precision 0.939265183704074

# %%
mnb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
import pickle
pickle.dump(tfidf,open('vectorizer1.pkl','wb'))
pickle.dump(ypred,open('model1.pkl','wb'))
